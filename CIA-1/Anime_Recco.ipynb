# %% [markdown]
# ### Import libraries:

# %%
import numpy as np
import pandas as pd
from typing import List, Tuple

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv("/kaggle/input/anime-recommendations-database/Anime_data.csv")
df.head()
# Out:
#    Anime_id                            Title  \
# 0         1                     Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira
# 2         6                           Trigun
# 3         7               Witch Hunter Robin
# 4         8                   Bouken Ou Beet
#
#                                                Genre  \
# 0  ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...
# 1  ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']
# 2  ['Action', 'Sci-Fi', 'Adventure', 'Comedy', 'D...
# 3  ['Action', 'Magic', 'Police', 'Supernatural', ...
# 4  ['Adventure', 'Fantasy', 'Shounen', 'Supernatu...
#
#                                             Synopsis   Type  \
# 0  In the year 2071, humanity has colonized sever...     TV
# 1  Another day, another bounty—such is the life o...  Movie
# 2  Vash the Stampede is the man with a $$60,000,0...     TV
# 3  Witches are individuals with special powers li...     TV
# 4  It is the dark century and the people are suff...     TV
#
#                        Producer              Studio  Rating  ScoredBy  \
# 0             ['Bandai Visual']         ['Sunrise']    8.81  363889.0
# 1  ['Sunrise', 'Bandai Visual']           ['Bones']    8.41  111187.0
# 2      ['Victor Entertainment']        ['Madhouse']    8.31  197451.0
# 3             ['Bandai Visual']         ['Sunrise']    7.34   31875.0
# 4                           NaN  ['Toei Animation']    7.04    4757.0
#
#    Popularity   Members  Episodes    Source                         Aired  \
# 0        39.0  704490.0      26.0  Original   Apr 3, 1998 to Apr 24, 1999
# 1       475.0  179899.0       1.0  Original                   Sep 1, 2001
# 2       158.0  372709.0      26.0     Manga   Apr 1, 1998 to Sep 30, 1998
# 3      1278.0   74889.0      26.0  Original   Jul 2, 2002 to Dec 24, 2002
# 4      3968.0   11247.0      52.0     Manga  Sep 30, 2004 to Sep 29, 2005
#
#                                                 Link
# 0       https://myanimelist.net/anime/1/Cowboy_Bebop
# 1  https://myanimelist.net/anime/5/Cowboy_Bebop__...
# 2             https://myanimelist.net/anime/6/Trigun
# 3  https://myanimelist.net/anime/7/Witch_Hunter_R...
# 4     https://myanimelist.net/anime/8/Bouken_Ou_Beet

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17002 entries, 0 to 17001
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Anime_id    17002 non-null  int64
#  1   Title       17002 non-null  object
#  2   Genre       14990 non-null  object
#  3   Synopsis    15583 non-null  object
#  4   Type        16368 non-null  object
#  5   Producer    7635 non-null   object
#  6   Studio      7919 non-null   object
#  7   Rating      14425 non-null  float64
#  8   ScoredBy    13227 non-null  float64
#  9   Popularity  16368 non-null  float64
#  10  Members     17002 non-null  float64
#  11  Episodes    14085 non-null  float64
#  12  Source      15075 non-null  object
#  13  Aired       16368 non-null  object
#  14  Link        16368 non-null  object
# dtypes: float64(5), int64(1), object(9)
# memory usage: 1.9+ MB

# %%
df.isnull().sum()
# Out:
# Anime_id         0
# Title            0
# Genre         2012
# Synopsis      1419
# Type           634
# Producer      9367
# Studio        9083
# Rating        2577
# ScoredBy      3775
# Popularity     634
# Members          0
# Episodes      2917
# Source        1927
# Aired          634
# Link           634
# dtype: int64

# %%
df_new = df[['Anime_id','Title','Genre','Rating']]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17002 entries, 0 to 17001
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Anime_id  17002 non-null  int64
#  1   Title     17002 non-null  object
#  2   Genre     14990 non-null  object
#  3   Rating    14425 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 531.4+ KB

# %%
clean_df_new = df_new.dropna()
clean_df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13076 entries, 0 to 15048
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Anime_id  13076 non-null  int64
#  1   Title     13076 non-null  object
#  2   Genre     13076 non-null  object
#  3   Rating    13076 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 510.8+ KB

# %%
clean_df_new.head(20)
# Out:
#     Anime_id                            Title  \
# 0          1                     Cowboy Bebop
# 1          5  Cowboy Bebop: Tengoku no Tobira
# 2          6                           Trigun
# 3          7               Witch Hunter Robin
# 4          8                   Bouken Ou Beet
# 5         15                     Eyeshield 21
# 6         16             Hachimitsu to Clover
# 7         17       Hungry Heart: Wild Striker
# 8         18           Initial D Fourth Stage
# 9         19                          Monster
# 10        20                           Naruto
# 11        21                        One Piece
# 12        22              Tennis no Ouji-sama
# 13        23                 Ring ni Kakero 1
# 14        24                    School Rumble
# 15        25                        Sunabouzu
# 16        26                       Texhnolyze
# 17        26                       Texhnolyze
# 18        27                    Trinity Blood
# 19        28                 Yakitate!! Japan
#
#                                                 Genre  Rating
# 0   ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...    8.81
# 1   ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']    8.41
# 2   ['Action', 'Sci-Fi', 'Adventure', 'Comedy', 'D...    8.31
# 3   ['Action', 'Magic', 'Police', 'Supernatural', ...    7.34
# 4   ['Adventure', 'Fantasy', 'Shounen', 'Supernatu...    7.04
# 5           ['Action', 'Sports', 'Comedy', 'Shounen']    8.05
# 6   ['Comedy', 'Drama', 'Josei', 'Romance', 'Slice...    8.14
# 7    ['Slice of Life', 'Comedy', 'Sports', 'Shounen']    7.69
# 8     ['Action', 'Cars', 'Sports', 'Drama', 'Seinen']    8.24
# 9   ['Drama', 'Horror', 'Mystery', 'Police', 'Psyc...    8.69
# 10  ['Action', 'Adventure', 'Comedy', 'Super Power...    7.88
# 11  ['Action', 'Adventure', 'Comedy', 'Super Power...    8.54
# 12  ['Action', 'Comedy', 'Sports', 'School', 'Shou...    8.01
# 13                    ['Action', 'Shounen', 'Sports']    6.59
# 14         ['Comedy', 'Romance', 'School', 'Shounen']    8.02
# 15  ['Action', 'Adventure', 'Comedy', 'Ecchi', 'Sc...    7.52
# 16     ['Action', 'Sci-Fi', 'Psychological', 'Drama']    7.78
# 17     ['Action', 'Sci-Fi', 'Psychological', 'Drama']    7.78
# 18              ['Action', 'Supernatural', 'Vampire']    7.41
# 19                              ['Comedy', 'Shounen']    8.02

# %%
class AnimeRecommendationBandit:
    def __init__(self, df: pd.DataFrame, epsilon: float = 0.1):
        self.df = df
        self.epsilon = epsilon
        self.anime_ids = df['Anime_id'].unique()
        self.n_arms = len(self.anime_ids)
        self.counts = {anime_id: 0 for anime_id in self.anime_ids}
        self.values = {anime_id: 0.0 for anime_id in self.anime_ids}

    def select_arm(self) -> int:
        if np.random.random() < self.epsilon:
            return np.random.choice(self.anime_ids)
        else:
            return max(self.values, key=self.values.get)

    def update(self, anime_id: int, reward: float):
        self.counts[anime_id] += 1
        n = self.counts[anime_id]
        value = self.values[anime_id]
        new_value = ((n - 1) / n) * value + (1 / n) * reward
        self.values[anime_id] = new_value

    def recommend(self, n_recommendations: int = 5) -> List[Tuple[int, str, float]]:
        recommendations = []
        for _ in range(n_recommendations):
            anime_id = self.select_arm()
            anime = self.df[self.df['Anime_id'] == anime_id].iloc[0]
            recommendations.append((anime_id, anime['Title'], self.values[anime_id]))
            self.update(anime_id, anime['Rating'])
        return recommendations

# %%
recommender = AnimeRecommendationBandit(df)

def get_recommendations(n_recommendations: int = 5):
    recommendations = recommender.recommend(n_recommendations)
    print(f"Top {n_recommendations} Recommendations:")
    for i, (anime_id, title, estimated_rating) in enumerate(recommendations, 1):
        print(f"{i}. {title} (ID: {anime_id}, Estimated Rating: {estimated_rating:.2f})")

# %%
get_recommendations(5)
# Out:
# Top 5 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 0.00)
# 2. Rolling☆Girls (ID: 25867, Estimated Rating: 0.00)
# 3. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# 4. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# 5. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)

# %%
for _ in range(100):
    get_recommendations(1)
# Out:
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Mahoutsukai no Yome: Gakuin-hen (ID: 40134, Estimated Rating: 0.00)
# Top 1 Recommendations:
# 1. Bakuon!! no Kobeya (ID: 34623, Estimated Rating: 0.00)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Shimajirou Movie: Mahou no Shima no Daibouken (ID: 36727, Estimated Rating: 0.00)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Karma (ID: 29661, Estimated Rating: 0.00)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Kyoto Animation Koushiki Twitter: Itsumo Arigatou (ID: 36799, Estimated Rating: 0.00)
# Top 1 Recommendations:
# 1. Gunslinger Girl: Il Teatrino OVA (ID: 4765, Estimated Rating: 0.00)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Ikkyuu Nyuukon (ID: 36121, Estimated Rating: 0.00)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Accel World (ID: 11759, Estimated Rating: 0.00)
# Top 1 Recommendations:
# 1. Tom Sawyer no Bouken (ID: 2577, Estimated Rating: 0.00)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Pink Lady Monogatari: Eikou no Tenshi-tachi Recaps (ID: 25601, Estimated Rating: 0.00)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Soratobu Toshi Keikaku (ID: 3818, Estimated Rating: 0.00)
# Top 1 Recommendations:
# 1. Dive to Blue (ID: 33689, Estimated Rating: 0.00)
# Top 1 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# Top 1 Recommendations:
# 1. Kurage no Shokudou (ID: 29301, Estimated Rating: 0.00)

# %%
print("\nFinal Recommendations after 100 interactions:")
get_recommendations(5)
# Out:
# Final Recommendations after 100 interactions:
# Top 5 Recommendations:
# 1. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# 2. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# 3. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# 4. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
# 5. Cowboy Bebop (ID: 1, Estimated Rating: 8.81)
